# %%
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['font.family'] = 'serif'

# %%
import pandas as pd

# %%
df = pd.read_csv('/users/linggeli/simulation_data_new.csv')

# %%
df.head()
# Out:
#          X1         X2         X3        X4        X5        X6         X7  \
# 0  0.413870  -5.261347  -3.533320 -0.270194 -3.689906 -4.546583  -3.536759
# 1 -0.416912  -5.327583  -9.122070 -2.507005 -3.369022  0.258063   2.496594
# 2  0.404002   1.677917   2.327948  0.727260 -1.457412 -3.956758  -3.494738
# 3 -0.947501  13.672927  19.554352  1.874470 -1.783709 -6.384849 -14.432446
# 4 -0.476740  -3.135296  -0.557029 -0.435685 -1.837159 -4.278063  -2.805285
#
#           X8        X9       X10  ...        F1        F2        F3        F4  \
# 0 -10.123385 -2.363940  7.141265  ...  0.986789 -0.888360  0.538189  0.912367
# 1  -6.110371  1.330298  2.629553  ...  0.987785 -0.890446  0.536605  0.913500
# 2  -2.134326 -1.224571  2.554755  ...  0.969272 -0.893435  0.537910  0.916507
# 3  -3.125946 -3.088987  6.602725  ...  1.000906 -0.893535  0.540015  0.910833
# 4  -9.248118 -2.445720  4.476319  ...  0.965929 -0.890603  0.539672  0.916193
#
#    seed  scenario   p   q  r  t
# 0     1         1  10  55  4  1
# 1     1         1  10  55  4  2
# 2     1         1  10  55  4  3
# 3     1         1  10  55  4  4
# 4     1         1  10  55  4  5
#
# [5 rows x 75 columns]

# %%
print(df.columns.values)
# Out:
# ['X1' 'X2' 'X3' 'X4' 'X5' 'X6' 'X7' 'X8' 'X9' 'X10' 'Y1' 'Y2' 'Y3' 'Y4'
#  'Y5' 'Y6' 'Y7' 'Y8' 'Y9' 'Y10' 'Y11' 'Y12' 'Y13' 'Y14' 'Y15' 'Y16' 'Y17'
#  'Y18' 'Y19' 'Y20' 'Y21' 'Y22' 'Y23' 'Y24' 'Y25' 'Y26' 'Y27' 'Y28' 'Y29'
#  'Y30' 'Y31' 'Y32' 'Y33' 'Y34' 'Y35' 'Y36' 'Y37' 'Y38' 'Y39' 'Y40' 'Y41'
#  'Y42' 'Y43' 'Y44' 'Y45' 'Y46' 'Y47' 'Y48' 'Y49' 'Y50' 'Y51' 'Y52' 'Y53'
#  'Y54' 'Y55' 'F1' 'F2' 'F3' 'F4' 'seed' 'scenario' 'p' 'q' 'r' 't']

# %%
sim_data_new = df.iloc[:, :69].values
print(sim_data_new.shape)
# Out:
# (200000, 69)

# %%
np.save('sim_data_new.npy', sim_data_new)

# %%
sim_data = np.load('simulation_data.npy')

# %%
length = 1000

scenario = 0
data_idx = 3

start = data_idx * length * 4 + scenario * length
end = start + length

# %%
X = np.asarray(sim_data[start:end, :5])
Y = np.asarray(sim_data[start:end, 5:20])
F = np.asarray(sim_data[start:end, 20:22])
print(X.shape)
print(Y.shape)
print(F.shape)
# Out:
# (1000, 5)
# (1000, 15)
# (1000, 2)

# %%
plt.plot(F[:, 0])
plt.plot(F[:, 1])
plt.show()

# %%
for j in range(15):
    plt.plot(Y[:, j])
plt.show()

# %%
for j in range(5):
    plt.plot(X[:, j])
plt.show()

# %%
from scipy.linalg import logm

# %% [markdown]
# ### SW + PCA + VAR

# %%
from sklearn.decomposition import PCA
from statsmodels.tsa.api import VAR

# %%
def sliding_window(time_series, size=50, stride=1):
    """
    Calculate sliding window covariance Log-Euclidean vector time series.
    
    Args
        time_series: (numpy array) [t, n] t observations in time of n dimensional data
        size: (int) sliding window size
        stride: (int) sliding step size
    """
    t, n = X.shape
    #cov_series = np.zeros((t - size, n, n))
    log_series = np.zeros((t - size, int(0.5 * n * (n + 1))))
    for i in range(t - size):
        sliding_window = time_series[(i * stride):(i * stride + size), :]
        cov = np.cov(sliding_window, rowvar=False)
        #cov_series[i, :, :] = cov
        log_series[i, :] = logm(cov)[np.triu_indices(n)]
    return log_series

# %%
log_series_hat = sliding_window(X)
pca = PCA(n_components=2)
components = pca.fit_transform(log_series_hat)

# %%
model = VAR(components)
results = model.fit(2)
fitted_components = np.zeros(components.shape)
fitted_components[:2, :] = components[:2, :]
fitted_components[2:, :] = results.fittedvalues
Y_hat = pca.inverse_transform(fitted_components)

# %%
for j in range(2):
    plt.plot(fitted_components[:, j])
    plt.plot(components[:, j], '--')
plt.show()

# %%
total = Y_hat.shape[0]
start = 25
mse = np.mean((Y[start:(start + total), :] - Y_hat) ** 2)
print(mse)
# Out:
# 0.22612645212920995

# %%
def prepare_data(sim_data, scenario, data_idx):
    length = 1000
    sample_size = 10
    start = data_idx * length * 4 + scenario * length
    end = start + length
    X = np.asarray(sim_data[start:end, :5])
    Y = np.asarray(sim_data[start:end, 5:20])
    F = np.asarray(sim_data[start:end, 20:22])
    return X, Y, F

# %%
def SW_PCA_VAR(X, Y, ws=50, r=2):
    log_series_hat = sliding_window(X, ws)
    pca = PCA(n_components=r)
    components = pca.fit_transform(log_series_hat)
    model = VAR(components)
    results = model.fit(2)
    fitted_components = np.zeros(components.shape)
    fitted_components[:2, :] = components[:2, :]
    fitted_components[2:, :] = results.fittedvalues
    Y_hat = pca.inverse_transform(fitted_components)
    return fitted_components, Y_hat

# %%
all_mse = np.zeros(50)
for i in range(50):
    X, Y, F = prepare_data(sim_data, 3, i)
    plt.plot(F[:, 0])
    plt.plot(F[:, 1])
    plt.show()
    fitted_components, Y_hat = SW_PCA_VAR(X, Y)
    for j in range(2):
        plt.plot(fitted_components[:, j])
    plt.show()
    total = Y_hat.shape[0]
    start = 25
    mse = np.mean((Y[start:(start + total), :] - Y_hat) ** 2)
    all_mse[i] = mse
    print(mse)
# Out:
# 0.6453684962530197
# 0.7533899665657151
# 0.02347229367837374
# 0.08314244020443494
# 0.9661582784050214
# 0.09767489590616162
# 0.17234508717944577
# 0.03644802373178729
# 0.23816244479594625
# 2.408949469707529
# 3.0277774781847016
# 0.4613200445438655
# 0.8291919682257354
# 0.29281554996951237
# 0.24248265834920552
# 0.7857442759975619
# 0.24858646422925362
# 0.5006295193507839
# 0.07447504546444457
# 0.031284620029705
# 0.567950727693172
# 0.2412804524490464
# 0.35097183992192665
# 0.492640127185485
# 0.11493879102906446
# 0.20339194648346468
# 0.018805658548362632
# 0.4267822394190369
# 0.18833193503930784
# 0.7860818331414343
# 0.13288432100481665
# 3.1010996202998515
# 0.07999319692806015
# 0.44692782030472994
# 0.130507957778494
# 1.230279493311609
# 0.3274046262226782
# 0.37565300559650644
# 0.02668559884551061
# 0.6451299602080753
# 0.25110604064864883
# 0.10169475694383474
# 0.09029542913876612
# 0.029382235780227514
# 0.0599053072630119
# 0.18763285009323452
# 0.25993456257747505
# 0.2886811372255377
# 1.5209305809277487
# 0.1985140655808682

# %%
plt.hist(all_mse)
plt.show()

# %%
print(np.mean(all_mse))
# Out:
# 0.49590474276724383

# %%
print(np.median(all_mse))
# Out:
# 0.24984625243895123
